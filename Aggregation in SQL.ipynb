# %% [markdown]
# ###ASSIGNMENT: Aggregation in SQL
#
# ---

# %% [markdown]
# **Question 1 : Count how many cities are there in each country?**

# %% [markdown]
# ![Screenshot 2026-01-21 135517.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Question 2 : Display all continents having more than 30 countries.**

# %% [markdown]
# ![Screenshot 2026-01-21 141149.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Question 3 : List regions whose total population exceeds 200 million.**

# %% [markdown]
# ![Screenshot 2026-01-21 143005.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Question 4 : Find the top 5 continents by average GNP per country.**

# %% [markdown]
# ![Screenshot 2026-01-21 144127.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Question 5 : Find the total number of official languages spoken in each continent.**

# %% [markdown]
# ![Screenshot 2026-01-21 145633.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Question 6 : Find the maximum and minimum GNP for each continent.**

# %% [markdown]
# ![Screenshot 2026-01-21 150234.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Question 7 : Find the country with the highest average city population.**

# %% [markdown]
# ![Screenshot 2026-01-21 162603.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Question 8 : List continents where the average city population is greater than 200,000.**

# %% [markdown]
# ![Screenshot 2026-01-21 163306.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Question 9 : Find the total population and average life expectancy for each continent, ordered by average life expectancy descending.**

# %% [markdown]
# ![Screenshot 2026-01-21 164520.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Question 10 : Find the top 3 continents with the highest average life expectancy, but only include those where the total population is over 200 million.**

# %% [markdown]
# ![Screenshot 2026-01-21 165354.png](data:image/png;base64,...)

# %% [markdown]
# ---
